from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.2.tar.gz (368 kB)
#      |################################| 368 kB 8.0 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-2x_wny3y/psycopg2_39aa378c71db4c5f9a4ca0a3d18009a4/setup.py'"'"'; __file__='"'"'/tmp/pip-install-2x_wny3y/psycopg2_39aa378c71db4c5f9a4ca0a3d18009a4/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-h7vbnzp1
#          cwd: /tmp/pip-install-2x_wny3y/psycopg2_39aa378c71db4c5f9a4ca0a3d18009a4/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-h7vbnzp1/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-h7vbnzp1/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-h7vbnzp1/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-h7vbnzp1/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-h7vbnzp1/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/23/7e/93c325482c328619870b6cd09370f6dbe1148283daca65115cd63642e60f/psycopg2-2.8.2.tar.gz#sha256=5cacf21b6f813c239f100ef78a4132056f93a5940219ec25d2ef833cbeb05588 (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.1.tar.gz (367 kB)
#      |################################| 367 kB 9.6 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-2x_wny3y/psycopg2_8533fb99557e489d8b232b5e2e445088/setup.py'"'"'; __file__='"'"'/tmp/pip-install-2x_wny3y/psycopg2_8533fb99557e489d8b232b5e2e445088/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-juybqj4f
#          cwd: /tmp/pip-install-2x_wny3y/psycopg2_8533fb99557e489d8b232b5e2e445088/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-juybqj4f/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-juybqj4f/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-juybqj4f/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-juybqj4f/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-juybqj4f/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/52/be/f898e712f5f08131d651a62754fca82a1deb42e4e9889ad01932f770a2be/psycopg2-2.8.1.tar.gz#sha256=b4a475ce87eabc0607e068a3c704d0aa0820237ed78d493b8e2d880eb73cd7fe (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.8.tar.gz (367 kB)
#      |################################| 367 kB 6.9 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-2x_wny3y/psycopg2_1b210ff345e4403faf805579f94fb4a2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-2x_wny3y/psycopg2_1b210ff345e4403faf805579f94fb4a2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-nf6ikfyf
#          cwd: /tmp/pip-install-2x_wny3y/psycopg2_1b210ff345e4403faf805579f94fb4a2/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-pip-egg-info-nf6ikfyf/psycopg2.egg-info
#     writing /tmp/pip-pip-egg-info-nf6ikfyf/psycopg2.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-nf6ikfyf/psycopg2.egg-info/dependency_links.txt
#     writing top-level names to /tmp/pip-pip-egg-info-nf6ikfyf/psycopg2.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-nf6ikfyf/psycopg2.egg-info/SOURCES.txt'
#
#     Error: pg_config executable not found.
#
#     pg_config is required to build psycopg2 from source.  Please add the directory
#     containing pg_config to the $PATH or specify the full executable path with the
#     option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#
#     If you prefer to avoid building psycopg2 from source, please install the PyPI
#     'psycopg2-binary' package instead.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <http://initd.org/psycopg/docs/install.html>).
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/c7/ca/75236b17f1b951950ffc55d657c5aa408d3d0327a1b6c4c0f7cb16ef7e7b/psycopg2-2.8.tar.gz#sha256=49c5838d90e83217909db3789d30a105385b5e696ec5168cda645546c542f35a (from https://pypi.org/simple/psycopg2/) (requires-python:>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading psycopg2-2.7.7-cp36-cp36m-manylinux1_x86_64.whl (2.7 MB)
#      |################################| 2.7 MB 11.5 MB/s eta 0:00:01
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.7.7
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import psycopg2
from psycopg2.extras import execute_values
import time
import requests
import numpy as np
import pandas as pd
import statistics
from scipy import stats, signal
from sklearn.model_selection import train_test_split
from scipy.stats import ttest_ind
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# # Conection and create table

# %%
def connect_postgress():
    """ open conexion to the PostgreSQL database"""
    conn = psycopg2.connect(
        host="postgres-data",
        port=5432,
        database="sc",
        user="postgres",
        password="postgres")
    return conn

def create_tables():
    """ create tables in the PostgreSQL database"""
    command = (
        """
        CREATE TABLE profiles (
            TIME FLOAT,
            MACHINE BIGINT,
            DATA VARCHAR(10000),
            MAX FLOAT,
            MEAN FLOAT,
            MIN FLOAT
        );
        CREATE TABLE p_value (
            TIME FLOAT,
            MACHINE BIGINT,
            PVALUE FLOAT
        )
        """)
    conn = None
    a = False
    try:
        # read the connection parameters
        #params = config()
        # connect to the PostgreSQL server
        #conn = psycopg2.connect(**params)
        conn = connect_postgress()
        cur = conn.cursor()
        # create table one by one
        #for command in commands:
        cur.execute(command)
        # close communication with the PostgreSQL database server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        a = True
    finally:
        if conn is not None:
            conn.close()
    return a

def drop_tables():
    """ create tables in the PostgreSQL database"""
    command = (
        """
        DROP TABLE IF EXISTS profiles;
        DROP TABLE IF EXISTS p_value
        """)
    conn = None
    a = False
    try:
        # read the connection parameters
        #params = config()
        # connect to the PostgreSQL server
        #conn = psycopg2.connect(**params)
        conn = connect_postgress()
        cur = conn.cursor()
        # create table one by one
        #for command in commands:
        cur.execute(command)
        # close communication with the PostgreSQL database server
        cur.close()
        # commit the changes
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        a = True
    finally:
        if conn is not None:
            conn.close()
    return a


def insert_values(table_name,values,sql):
    """ insert a new vendor into the vendors table """
    conn = None
    vendor_id = None
    print(sql)
    try:
        # read database configuration
        # params = config()
        # connect to the PostgreSQL database
        conn = connect_postgress()
        #conn = psycopg2.connect(**params)
        # create a new cursor
        cur = conn.cursor()
        # execute the INSERT statement
        # cur.execute(sql, (values,))
        # execute the SQL statement
        execute_values(cur, sql, values)

        # get the generated id back
        #cur.fetchone()
        # cur.fetchall()
        # commit the changes to the database
        conn.commit()
        # close communication with the database
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        id_values = None
    finally:
        if conn is not None:
            conn.close()

# %% [markdown]
# ### Run simulator

# %%
def run_simulator(num_machines = 1,step = 0.001, sleep = 2, cycles = 2000, drop = True):
    if drop:
        a = drop_tables()
    a = create_tables()
    
    n = 0
    base = 365.25*24*60*60
    timestamp = 0
    headers = {'Content-Type': "application/json", 'Accept': "application/json"}
    
    #START P_VALUE
    table_name = "p_value"
    values = [("0","0","1"),("0","1","1"),("0","2","1")]
    sql = """INSERT INTO """+table_name+""" (TIME,MACHINE,PVALUE) VALUES %s """
    insert_values(table_name,values,sql)
    
    while n != cycles:
        print("timestamp: ",timestamp)
        json = str(int(timestamp))
        for machine in range(num_machines):
            r = requests.get('http://172.16.56.53:5001/get_curve_time',json=json,headers=headers)
            values = r.json()
            max_val, mean_val, min_val = max(values), np.mean(values), min(values)
            value = [(str(timestamp), 
                      str(machine), 
                      str(values), 
                      str(max_val), 
                      str(mean_val), 
                      str(min_val))]
            table_name = "profiles"
            sql = """INSERT INTO """+table_name+""" (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s """
            insert_values(table_name,value,sql)
        time.sleep(sleep)
        timestamp = timestamp + base * step
        n = n + 1

# %%
run_simulator(num_machines = 3)
# Out:
# INSERT INTO p_value (TIME,MACHINE,PVALUE) VALUES %s
# timestamp:  0
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  31557.600000000002
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  63115.200000000004
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  94672.8
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  126230.40000000001
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  157788.0
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  189345.6
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  220903.2
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  252460.80000000002
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  284018.4
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  315576.0
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  347133.6
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  378691.19999999995
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  410248.79999999993
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  441806.3999999999
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# timestamp:  473363.9999999999
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
# INSERT INTO profiles (TIME,MACHINE,DATA,MAX,MEAN,MIN) VALUES %s
